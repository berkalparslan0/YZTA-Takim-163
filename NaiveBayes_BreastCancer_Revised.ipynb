# %% [markdown]
# # Naive Bayes ile Meme Kanseri Teşhisi

# %%
# Naive Bayes ile Meme Kanseri Teşhisi

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, auc

# Veriyi yükle
df = pd.read_csv("data.csv")
df.dropna(inplace=True)

# Özellikler ve hedef
X = df.drop('diagnosis', axis=1)
y = df['diagnosis']

# Etiketleri sayısallaştır
le = LabelEncoder()
y_encoded = le.fit_transform(y)  # B=0, M=1

# Eğitim/test bölme
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# Model oluştur ve eğit
model = GaussianNB()
model.fit(X_train, y_train)

# Tahmin yap
y_pred = model.predict(X_test)
print("Doğruluk Oranı:", accuracy_score(y_test, y_pred))

# Confusion matrix
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Tahmin")
plt.ylabel("Gerçek")
plt.show()

# Sınıflandırma raporu
print("Sınıflandırma Raporu:\n", classification_report(y_test, y_pred, target_names=le.classes_))

# ROC Eğrisi
y_prob = model.predict_proba(X_test)[:, 1]
fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label='ROC Eğrisi (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Eğrisi')
plt.legend(loc="lower right")
plt.show()

# %%
# Kullanıcıdan giriş alarak tahmin yap
print("Yeni hasta verisini giriniz:")
input_values = []
val = float(input("id: "))
input_values.append(val)
val = float(input("radius_mean: "))
input_values.append(val)
val = float(input("texture_mean: "))
input_values.append(val)
val = float(input("perimeter_mean: "))
input_values.append(val)
val = float(input("area_mean: "))
input_values.append(val)
val = float(input("smoothness_mean: "))
input_values.append(val)
val = float(input("compactness_mean: "))
input_values.append(val)
val = float(input("concavity_mean: "))
input_values.append(val)
val = float(input("concave points_mean: "))
input_values.append(val)
val = float(input("symmetry_mean: "))
input_values.append(val)
val = float(input("fractal_dimension_mean: "))
input_values.append(val)
val = float(input("radius_se: "))
input_values.append(val)
val = float(input("texture_se: "))
input_values.append(val)
val = float(input("perimeter_se: "))
input_values.append(val)
val = float(input("area_se: "))
input_values.append(val)
val = float(input("smoothness_se: "))
input_values.append(val)
val = float(input("compactness_se: "))
input_values.append(val)
val = float(input("concavity_se: "))
input_values.append(val)
val = float(input("concave points_se: "))
input_values.append(val)
val = float(input("symmetry_se: "))
input_values.append(val)
val = float(input("fractal_dimension_se: "))
input_values.append(val)
val = float(input("radius_worst: "))
input_values.append(val)
val = float(input("texture_worst: "))
input_values.append(val)
val = float(input("perimeter_worst: "))
input_values.append(val)
val = float(input("area_worst: "))
input_values.append(val)
val = float(input("smoothness_worst: "))
input_values.append(val)
val = float(input("compactness_worst: "))
input_values.append(val)
val = float(input("concavity_worst: "))
input_values.append(val)
val = float(input("concave points_worst: "))
input_values.append(val)
val = float(input("symmetry_worst: "))
input_values.append(val)
val = float(input("fractal_dimension_worst: "))
input_values.append(val)

input_array = pd.DataFrame([input_values], columns=X.columns)
predicted = model.predict(input_array)[0]

print("Tahmin Sonucu:", "Kötü Huylu (Malignant)" if predicted == 1 else "İyi Huylu (Benign)")
